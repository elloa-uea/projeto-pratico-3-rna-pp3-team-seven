# %% [markdown]
# ## Redes Neurais Artificiais 2020.1
#
# **Disciplina**: Redes Neurais Artificiais 2020.1
# **Professora**: Elloá B. Guedes (ebgcosta@uea.edu.br)
# **Github**: http://github.com/elloa
#
# ### Explorando uma base de dados
#
# Nesta atividade prática iremos explorar a seguinte base de dados **_Forest Cover Type_**
#
# 1. Obtenha esta base de dados no seguinte link: https://www.kaggle.com/uciml/forest-cover-type-dataset/download
# 2. Consulte a documentação oficial da base de dados: https://archive.ics.uci.edu/ml/datasets/covertype
# 3. **Responda**:
#   3.1 O que é cada exemplo na base de dados?
#   3.2 Em que ano ela foi obtida?
#   3.3 Quem foram os responsáveis pela criação desta base de dados?

# %%
## Reservado para a importação de bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Type Markdown and LaTeX:  𝛼2

# %% [markdown]
# ### Manipulando a base de dados
#
# 1. Abra a base de dados com o pandas
# 2. Imprima os 10 primeiros exemplos pertencentes à esta base
# 3. Imprima os 10 últimos exemplos pertencentes à esta base
# 4. Quantos exemplos esta base de dados possui?
# 5. Quais são os atributos que a base de dados possui e quais seus tipos?
# 6. Há algum dado faltante na base?
# 7. De acordo com a documentação da base de dados, qual o significado dos atributos do tipo "Soil Type"?
#   7.1 Este atributo é quantitativo ou qualitativo?
#   7.2 Qual o tipo de codificação utilizada para denotar este atributo? Consulte a seguinte referência:
#   * https://pbpython.com/categorical-encoding.html

# %%
dados = pd.read_csv("covtype.csv")
dados.head(10)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-198-0169778656db> in <module>
# ----> 1 dados = pd.read_csv("covtype.csv")
#       2 dados.head(10)
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     456
#     457     try:
# --> 458         data = parser.read(nrows)
#     459     finally:
#     460         parser.close()
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1199             new_rows = len(index)
#    1200
# -> 1201         df = DataFrame(col_dict, columns=columns, index=index)
#    1202
#    1203         self._currow += new_rows
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     465
#     466         elif isinstance(data, dict):
# --> 467             mgr = init_dict(data, index, columns, dtype=dtype)
#     468         elif isinstance(data, ma.MaskedArray):
#     469             import numpy.ma.mrecords as mrecords
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      91     axes = [columns, index]
#      92
# ---> 93     return create_block_manager_from_arrays(arrays, arr_names, axes)
#      94
#      95
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1648
#    1649     try:
# -> 1650         blocks = form_blocks(arrays, names, axes)
#    1651         mgr = BlockManager(blocks, axes)
#    1652         mgr._consolidate_inplace()
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in form_blocks(arrays, names, axes)
#    1718
#    1719     if len(items_dict["IntBlock"]):
# -> 1720         int_blocks = _multi_blockify(items_dict["IntBlock"])
#    1721         blocks.extend(int_blocks)
#    1722
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in _multi_blockify(tuples, dtype)
#    1800     for dtype, tup_block in grouper:
#    1801
# -> 1802         values, placement = _stack_arrays(list(tup_block), dtype)
#    1803
#    1804         block = make_block(values, placement=placement)
#
# c:\users\luiz fabio\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
#    1828     shape = (len(arrays),) + _shape_compat(first)
#    1829
# -> 1830     stacked = np.empty(shape, dtype=dtype)
#    1831     for i, arr in enumerate(arrays):
#    1832         stacked[i] = _asarray_compat(arr)
#
# MemoryError: Unable to allocate 244. MiB for an array with shape (55, 581012) and data type int64

# %%
dados.tail(10)
# Out:
#         Elevation  Aspect  Slope  Horizontal_Distance_To_Hydrology  \
# 581002       2419     168     25                               108
# 581003       2415     161     25                                95
# 581004       2410     158     24                                90
# 581005       2405     159     22                                90
# 581006       2401     157     21                                90
# 581007       2396     153     20                                85
# 581008       2391     152     19                                67
# 581009       2386     159     17                                60
# 581010       2384     170     15                                60
# 581011       2383     165     13                                60
#
#         Vertical_Distance_To_Hydrology  Horizontal_Distance_To_Roadways  \
# 581002                              33                              124
# 581003                              29                              120
# 581004                              24                              120
# 581005                              19                              120
# 581006                              15                              120
# 581007                              17                              108
# 581008                              12                               95
# 581009                               7                               90
# 581010                               5                               90
# 581011                               4                               67
#
#         Hillshade_9am  Hillshade_Noon  Hillshade_3pm  \
# 581002            230             240            126
# 581003            236             237            116
# 581004            238             236            115
# 581005            237             238            119
# 581006            238             238            119
# 581007            240             237            118
# 581008            240             237            119
# 581009            236             241            130
# 581010            230             245            143
# 581011            231             244            141
#
#         Horizontal_Distance_To_Fire_Points  ...  Soil_Type32  Soil_Type33  \
# 581002                                 812  ...            0            0
# 581003                                 815  ...            0            0
# 581004                                 819  ...            0            0
# 581005                                 824  ...            0            0
# 581006                                 830  ...            0            0
# 581007                                 837  ...            0            0
# 581008                                 845  ...            0            0
# 581009                                 854  ...            0            0
# 581010                                 864  ...            0            0
# 581011                                 875  ...            0            0
#
#         Soil_Type34  Soil_Type35  Soil_Type36  Soil_Type37  Soil_Type38  \
# 581002            0            0            0            0            0
# 581003            0            0            0            0            0
# 581004            0            0            0            0            0
# 581005            0            0            0            0            0
# 581006            0            0            0            0            0
# 581007            0            0            0            0            0
# 581008            0            0            0            0            0
# 581009            0            0            0            0            0
# 581010            0            0            0            0            0
# 581011            0            0            0            0            0
#
#         Soil_Type39  Soil_Type40  Cover_Type
# 581002            0            0           3
# 581003            0            0           3
# 581004            0            0           3
# 581005            0            0           3
# 581006            0            0           3
# 581007            0            0           3
# 581008            0            0           3
# 581009            0            0           3
# 581010            0            0           3
# 581011            0            0           3
#
# [10 rows x 55 columns]

# %%
dados.shape
# Out:
# (581012, 55)

# %%
col = list(dados.columns)
col
# Out:
# ['Elevation',
#  'Aspect',
#  'Slope',
#  'Horizontal_Distance_To_Hydrology',
#  'Vertical_Distance_To_Hydrology',
#  'Horizontal_Distance_To_Roadways',
#  'Hillshade_9am',
#  'Hillshade_Noon',
#  'Hillshade_3pm',
#  'Horizontal_Distance_To_Fire_Points',
#  'Wilderness_Area1',
#  'Wilderness_Area2',
#  'Wilderness_Area3',
#  'Wilderness_Area4',
#  'Soil_Type1',
#  'Soil_Type2',
#  'Soil_Type3',
#  'Soil_Type4',
#  'Soil_Type5',
#  'Soil_Type6',
#  'Soil_Type7',
#  'Soil_Type8',
#  'Soil_Type9',
#  'Soil_Type10',
#  'Soil_Type11',
#  'Soil_Type12',
#  'Soil_Type13',
#  'Soil_Type14',
#  'Soil_Type15',
#  'Soil_Type16',
#  'Soil_Type17',
#  'Soil_Type18',
#  'Soil_Type19',
#  'Soil_Type20',
#  'Soil_Type21',
#  'Soil_Type22',
#  'Soil_Type23',
#  'Soil_Type24',
#  'Soil_Type25',
#  'Soil_Type26',
#  'Soil_Type27',
#  'Soil_Type28',
#  'Soil_Type29',
#  'Soil_Type30',
#  'Soil_Type31',
#  'Soil_Type32',
#  'Soil_Type33',
#  'Soil_Type34',
#  'Soil_Type35',
#  'Soil_Type36',
#  'Soil_Type37',
#  'Soil_Type38',
#  'Soil_Type39',
#  'Soil_Type40',
#  'Cover_Type']

# %%
data_type = list(dados.dtypes)
data_type
# Out:
# [dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64'),
#  dtype('int64')]

# %%
### 7.1
# Atributo qualitativo

### 7.2
# codificação binaria (0 ou 1)

# %% [markdown]
# ### Visualizando a base de dados
#
# 1. Baseando-se nos fundamentos de visualização de dados abordados na disciplina, plote cada um dos atributos preditores de maneira a enfatizar a sua distribuição, tendência central e dispersão
# Considere que o número de columas no dataset é diferente do número de atributos, conforme discussão promovida a respeito do dataset
# Se preferir, opte por complementar as informações visuais com medidas estatísticas
# 2. A partir da visualização elaborada, o que pode-se dizer a respeito do balanceamento do atributo-alvo?
# 3. Que tipo de tarefa de Aprendizado de Máquina é sugestiva para este problema?
# Apresente métricas de desempenho compatíveis para a avaliação do problema (liste-as)
# Escolha uma das métricas apresentadas para ser utilizada como referência pela equipe

# %%
# 1. Baseando-se nos fundamentos de visualização de dados abordados na disciplina, plote cada um
# dos atributos preditores de maneira a enfatizar a sua distribuição, tendência central e dispersão 

plt.rcParams["figure.figsize"] = [10,4]
def statistics(arr):
    mean = np.mean(arr)
    median = np.median(arr)
    var = np.var(arr)
    std = np.std(arr)
    
    result = [round(mean, 2), round(median, 2), round(var, 2), round(std, 2)]
    text = "Average: "+str(result[0])+"\nMedian: "+str(result[1])+"\nVariance: "+str(result[2])+"\nStandard deviation:"+str(result[3])
    
    return text

# %%
def graph_generator(attribute, point_size=2):
    # Number of occurrences for each 'Attribute' attribute value
    new_data = dados[attribute].value_counts()

    # Exclusive 'Attribute' dataframe
    new_data_df = list(zip(new_data.index, new_data))
    new_data_df = pd.DataFrame(new_data_df, columns = [attribute, 'Number of occurrences'])

    # Graphic
    ax = new_data_df.plot.scatter(x=attribute,y='Number of occurrences', s=point_size, colormap='viridis')
    ax.set_title(attribute+' / Number of occurrences')
    props = dict(boxstyle='Sawtooth', facecolor='white', alpha=0.3, pad=.5)
    ax.text(1.1, 1, statistics(new_data_df['Number of occurrences']), transform=ax.transAxes, fontsize=12, verticalalignment='top', bbox=props)

# %%
graph_generator('Elevation')
graph_generator('Aspect')

# %%
graph_generator('Slope')
graph_generator('Horizontal_Distance_To_Hydrology')

# %%
graph_generator('Vertical_Distance_To_Hydrology')
graph_generator('Horizontal_Distance_To_Roadways')

# %%
graph_generator('Hillshade_9am')
graph_generator('Hillshade_Noon')

# %%
graph_generator('Hillshade_3pm')
graph_generator('Horizontal_Distance_To_Fire_Points')

# %%
# 2. A partir da visualização elaborada, o que pode-se dizer a respeito do balanceamento do atributo-alvo?

# Existe um nítido desequilíbrio entre o conjunto de valores 1 e 2 com os demais valores do Cover_Type, sendo eles: 3, 4, 5, 6 e 7; 

graph_generator('Cover_Type',90)

for i in range(1,8):
    print("Quantidade de valores do valor \"{:d}\" é {:d}".format(i,dados.loc[dados['Cover_Type'] == i].shape[0]))
# Out:
# Quantidade de valores do valor "1" é 211840
# Quantidade de valores do valor "2" é 283301
# Quantidade de valores do valor "3" é 35754
# Quantidade de valores do valor "4" é 2747
# Quantidade de valores do valor "5" é 9493
# Quantidade de valores do valor "6" é 17367
# Quantidade de valores do valor "7" é 20510
